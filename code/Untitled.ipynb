# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_1=pd.read_csv("datas/Global_active_power.csv",delimiter=",",header=0)
data_2=pd.read_csv("datas/Global_intensity.csv",delimiter=",",header=0)
data_3=pd.read_csv("datas/Global_reactive_power.csv",delimiter=",",header=0)
data_4=pd.read_csv("datas/Voltage.csv",delimiter=",",header=0)
data_1
# Out:
#                    Datetime  Global_active_power
# 0       2010-01-01 00:00:00                1.790
# 1       2010-01-01 00:01:00                1.780
# 2       2010-01-01 00:02:00                1.780
# 3       2010-01-01 00:03:00                1.746
# 4       2010-01-01 00:04:00                1.686
# ...                     ...                  ...
# 457390  2010-11-26 20:58:00                0.946
# 457391  2010-11-26 20:59:00                0.944
# 457392  2010-11-26 21:00:00                0.938
# 457393  2010-11-26 21:01:00                0.934
# 457394  2010-11-26 21:02:00                0.932
#
# [457395 rows x 2 columns]

# %%
data_2
# Out:
#                    Datetime  Global_intensity
# 0       2010-01-01 00:00:00               7.4
# 1       2010-01-01 00:01:00               7.4
# 2       2010-01-01 00:02:00               7.4
# 3       2010-01-01 00:03:00               7.2
# 4       2010-01-01 00:04:00               7.0
# ...                     ...               ...
# 457390  2010-11-26 20:58:00               4.0
# 457391  2010-11-26 20:59:00               4.0
# 457392  2010-11-26 21:00:00               3.8
# 457393  2010-11-26 21:01:00               3.8
# 457394  2010-11-26 21:02:00               3.8
#
# [457395 rows x 2 columns]

# %%
all1=pd.merge(data_1,data_2, on=["Datetime"])
all1
# Out:
#                    Datetime  Global_active_power  Global_intensity
# 0       2010-01-01 00:00:00                1.790               7.4
# 1       2010-01-01 00:01:00                1.780               7.4
# 2       2010-01-01 00:02:00                1.780               7.4
# 3       2010-01-01 00:03:00                1.746               7.2
# 4       2010-01-01 00:04:00                1.686               7.0
# ...                     ...                  ...               ...
# 457390  2010-11-26 20:58:00                0.946               4.0
# 457391  2010-11-26 20:59:00                0.944               4.0
# 457392  2010-11-26 21:00:00                0.938               3.8
# 457393  2010-11-26 21:01:00                0.934               3.8
# 457394  2010-11-26 21:02:00                0.932               3.8
#
# [457395 rows x 3 columns]

# %%
all2=pd.merge(data_3,data_4, on=["Datetime"])
all2
# Out:
#                    Datetime  Global_reactive_power  Voltage
# 0       2010-01-01 00:00:00                  0.236   240.65
# 1       2010-01-01 00:01:00                  0.234   240.07
# 2       2010-01-01 00:02:00                  0.234   240.15
# 3       2010-01-01 00:03:00                  0.186   240.26
# 4       2010-01-01 00:04:00                  0.102   240.12
# ...                     ...                    ...      ...
# 457390  2010-11-26 20:58:00                  0.000   240.43
# 457391  2010-11-26 20:59:00                  0.000   240.00
# 457392  2010-11-26 21:00:00                  0.000   239.82
# 457393  2010-11-26 21:01:00                  0.000   239.70
# 457394  2010-11-26 21:02:00                  0.000   239.55
#
# [457395 rows x 3 columns]

# %%
alldata=pd.merge(all1,all2, on=["Datetime"])
alldata
# Out:
#                    Datetime  Global_active_power  Global_intensity  \
# 0       2010-01-01 00:00:00                1.790               7.4
# 1       2010-01-01 00:01:00                1.780               7.4
# 2       2010-01-01 00:02:00                1.780               7.4
# 3       2010-01-01 00:03:00                1.746               7.2
# 4       2010-01-01 00:04:00                1.686               7.0
# ...                     ...                  ...               ...
# 457390  2010-11-26 20:58:00                0.946               4.0
# 457391  2010-11-26 20:59:00                0.944               4.0
# 457392  2010-11-26 21:00:00                0.938               3.8
# 457393  2010-11-26 21:01:00                0.934               3.8
# 457394  2010-11-26 21:02:00                0.932               3.8
#
#         Global_reactive_power  Voltage
# 0                       0.236   240.65
# 1                       0.234   240.07
# 2                       0.234   240.15
# ...

# %%
alldata1= alldata.resample("D").sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-9a4bbf3d120d> in <module>
# ----> 1 alldata1= alldata.resample("D").sum()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8367
#    8368         axis = self._get_axis_number(axis)
# -> 8369         return get_resampler(
#    8370             self,
#    8371             freq=rule,
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in get_resampler(obj, kind, **kwds)
#    1309     """
#    1310     tg = TimeGrouper(**kwds)
# -> 1311     return tg._get_resampler(obj, kind=kind)
#    1312
#    1313
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in _get_resampler(self, obj, kind)
#    1474             return TimedeltaIndexResampler(obj, groupby=self, axis=self.axis)
#    1475
# ...

# %%
data_d=alldata.resample('D').mean()
data_d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-4c7595e0e76b> in <module>
# ----> 1 data_d=alldata.resample('D').mean()
#       2 data_d
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8367
#    8368         axis = self._get_axis_number(axis)
# -> 8369         return get_resampler(
#    8370             self,
#    8371             freq=rule,
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in get_resampler(obj, kind, **kwds)
#    1309     """
#    1310     tg = TimeGrouper(**kwds)
# -> 1311     return tg._get_resampler(obj, kind=kind)
#    1312
#    1313
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in _get_resampler(self, obj, kind)
#    1474             return TimedeltaIndexResampler(obj, groupby=self, axis=self.axis)
# ...
